# %% [markdown]
# <a href="https://colab.research.google.com/github/JaymersonFerreira/tratar-valores-vazios/blob/main/limpeza_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Identificando valores vazios

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("clientes.csv")
display(df)

#se tiver algum dados que não seja número, subistitua por vazio
df["TotalGasto"] = pd.to_numeric(df["TotalGasto"], errors="coerce")

# info
print(df.info())
# df.isna().any() ou .sum
#Mostra quando se a valores vazios na tabela
# print(df.isna().any())
print(df.isna().sum())
# Out:
#        IDCliente Dependentes  MesesComoCliente TipoContrato    FormaPagamento  \
# 0     7010-BRBUU         Sim              72.0       2 anos     CartaoCredito
# 1     9688-YGXVR         Nao               NaN       Mensal     CartaoCredito
# 2     9286-DOJGF         Nao               NaN       Mensal  DebitoAutomatico
# 3     6994-KERXL         Nao               4.0       Mensal  BoletoEletronico
# 4     2181-UAESM         Nao               2.0       Mensal  BoletoEletronico
# ...          ...         ...               ...          ...               ...
# 5981  0684-AOSIH         Nao               1.0       Mensal  BoletoEletronico
# 5982  5982-PSMKW         Sim              23.0       2 anos     CartaoCredito
# 5983  8044-BGWPI         Sim              12.0       Mensal  BoletoEletronico
# 5984  7450-NWRTR         Nao              12.0       Mensal  BoletoEletronico
# 5985  4795-UXVCJ         Nao              26.0        Anual     CartaoCredito
#
#      TotalGasto
# ...

# %% [markdown]
# # Valores vazios não identificaados como vazio

# %%
# identifica na hora de importar
# valores_vazios = ["?","-"]
# df = pd.read_csv("clientes.csv", na_values=valores_vazios)



# identifica com replace
#
df = df.replace({"?": np.nan, "-": np.nan})
display(df)
# Out:
#        IDCliente Dependentes  MesesComoCliente TipoContrato    FormaPagamento  \
# 0     7010-BRBUU         Sim              72.0       2 anos     CartaoCredito
# 1     9688-YGXVR         Nao               NaN       Mensal     CartaoCredito
# 2     9286-DOJGF         Nao               NaN       Mensal  DebitoAutomatico
# 3     6994-KERXL         Nao               4.0       Mensal  BoletoEletronico
# 4     2181-UAESM         Nao               2.0       Mensal  BoletoEletronico
# ...          ...         ...               ...          ...               ...
# 5981  0684-AOSIH         Nao               1.0       Mensal  BoletoEletronico
# 5982  5982-PSMKW         Sim              23.0       2 anos     CartaoCredito
# 5983  8044-BGWPI         Sim              12.0       Mensal  BoletoEletronico
# 5984  7450-NWRTR         Nao              12.0       Mensal  BoletoEletronico
# 5985  4795-UXVCJ         Nao              26.0        Anual     CartaoCredito
#
#       TotalGasto
# ...

# %% [markdown]
# # Removendo valores vazios

# %%
# joga fora o valor vazio
# dropna()

# 0 -> exclui linhas, 1 ->exclui colunas
# all -> quando todos os valores estiverem vazios
# any -> quando tiver algum um dado vazio
df = df.dropna(how='any', axis=0)

# %% [markdown]
# # Tratar valores vazios
# - Preenchendo com valores fixo

# %%
media = df["MesesComoCliente"].mean()
df["MesesComoCliente"] = df["MesesComoCliente"].fillna(media)
display(df)
# Out:
#        IDCliente Dependentes  MesesComoCliente TipoContrato    FormaPagamento  \
# 0     7010-BRBUU         Sim              72.0       2 anos     CartaoCredito
# 3     6994-KERXL         Nao               4.0       Mensal  BoletoEletronico
# 4     2181-UAESM         Nao               2.0       Mensal  BoletoEletronico
# 5     4312-GVYNH         Nao              70.0       2 anos  DebitoAutomatico
# 6     2495-KZNFB         Nao              33.0       Mensal  BoletoEletronico
# ...          ...         ...               ...          ...               ...
# 5981  0684-AOSIH         Nao               1.0       Mensal  BoletoEletronico
# 5982  5982-PSMKW         Sim              23.0       2 anos     CartaoCredito
# 5983  8044-BGWPI         Sim              12.0       Mensal  BoletoEletronico
# 5984  7450-NWRTR         Nao              12.0       Mensal  BoletoEletronico
# 5985  4795-UXVCJ         Nao              26.0        Anual     CartaoCredito
#
#       TotalGasto
# ...

# %% [markdown]
# - Preenchendo com anterior ou seguinte

# %%
df["MesesComoCliente"] = df["MesesComoCliente"].fillna(method="ffill")
display(df)
# Out:
#        IDCliente Dependentes  MesesComoCliente TipoContrato    FormaPagamento  \
# 0     7010-BRBUU         Sim              72.0       2 anos     CartaoCredito
# 1     9688-YGXVR         Nao              72.0       Mensal     CartaoCredito
# 2     9286-DOJGF         Nao              72.0       Mensal  DebitoAutomatico
# 3     6994-KERXL         Nao               4.0       Mensal  BoletoEletronico
# 4     2181-UAESM         Nao               2.0       Mensal  BoletoEletronico
# ...          ...         ...               ...          ...               ...
# 5981  0684-AOSIH         Nao               1.0       Mensal  BoletoEletronico
# 5982  5982-PSMKW         Sim              23.0       2 anos     CartaoCredito
# 5983  8044-BGWPI         Sim              12.0       Mensal  BoletoEletronico
# 5984  7450-NWRTR         Nao              12.0       Mensal  BoletoEletronico
# 5985  4795-UXVCJ         Nao              26.0        Anual     CartaoCredito
#
#       TotalGasto
# ...

# %% [markdown]
# - Interpolando

# %%
df["MesesComoCliente"] = df["MesesComoCliente"].interpolate()
display(df)
# Out:
#        IDCliente Dependentes  MesesComoCliente TipoContrato    FormaPagamento  \
# 0     7010-BRBUU         Sim         72.000000       2 anos     CartaoCredito
# 1     9688-YGXVR         Nao         49.333333       Mensal     CartaoCredito
# 2     9286-DOJGF         Nao         26.666667       Mensal  DebitoAutomatico
# 3     6994-KERXL         Nao          4.000000       Mensal  BoletoEletronico
# 4     2181-UAESM         Nao          2.000000       Mensal  BoletoEletronico
# ...          ...         ...               ...          ...               ...
# 5981  0684-AOSIH         Nao          1.000000       Mensal  BoletoEletronico
# 5982  5982-PSMKW         Sim         23.000000       2 anos     CartaoCredito
# 5983  8044-BGWPI         Sim         12.000000       Mensal  BoletoEletronico
# 5984  7450-NWRTR         Nao         12.000000       Mensal  BoletoEletronico
# 5985  4795-UXVCJ         Nao         26.000000        Anual     CartaoCredito
#
#       TotalGasto
# ...
